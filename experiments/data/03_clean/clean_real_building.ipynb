# %%
# %pip install seaborn matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import pandas as pd

directory = f"{os.getcwd()}/.."
building_df = pd.read_parquet(f"{directory}/02_standard/building_real.parquet")
building_df.head(1)
# Out:
#                            month  hour  day_type  daylight_savings_status  \
# datetime
# 2023-01-01 00:00:00+00:00      1     1         6                        0
#
#                            indoor_dry_bulb_temperature  \
# datetime
# 2023-01-01 00:00:00+00:00                          0.0
#
#                            average_unmet_cooling_setpoint_difference  \
# datetime
# 2023-01-01 00:00:00+00:00                                        0.0
#
#                            indoor_relative_humidity  non_shiftable_load  \
# datetime
# 2023-01-01 00:00:00+00:00                       0.0                 0.0
#
#                            dhw_demand  cooling_demand  heating_demand  \
# datetime
# 2023-01-01 00:00:00+00:00         0.0             0.0             0.0
#
#                            solar_generation  occupant_count  \
# datetime
# 2023-01-01 00:00:00+00:00               0.0             0.0
#
#                            indoor_dry_bulb_temperature_cooling_set_point  \
# ...

# %%
building_df[500:540].head(50)
# Out:
#                            month  hour  day_type  daylight_savings_status  \
# datetime
# 2023-01-21 20:00:00+00:00      1    21         5                        0
# 2023-01-21 21:00:00+00:00      1    22         5                        0
# 2023-01-21 22:00:00+00:00      1    23         5                        0
# 2023-01-21 23:00:00+00:00      1    24         5                        0
# 2023-01-22 00:00:00+00:00      1     1         6                        0
# 2023-01-22 01:00:00+00:00      1     2         6                        0
# 2023-01-22 02:00:00+00:00      1     3         6                        0
# 2023-01-22 03:00:00+00:00      1     4         6                        0
# 2023-01-22 04:00:00+00:00      1     5         6                        0
# 2023-01-22 05:00:00+00:00      1     6         6                        0
# 2023-01-22 06:00:00+00:00      1     7         6                        0
# ...

# %%
## see if distribution of days is good
import seaborn as sns
sns.displot(data=building_df, x="day_type")

# %%
## save building data
import os

cwd = os.getcwd()
building_df.to_parquet(f"{cwd}/building_real.parquet")
building_df.to_csv(f"{cwd}/building_real.csv", index=False)
